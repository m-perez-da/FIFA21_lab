# %%
import pandas as pd
import numpy as np
import math

# %%
data = pd.read_csv('fifa21_train.csv')
data.head()
# Out:
#        ID           Name  Age  Nationality                        Club   BP  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    Position                               Team & Contract Height  Weight  ...  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  ...
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  ...
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs  ...
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs  ...
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  ...
#
#     CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
# 3  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2   59
# 4  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2   65
#
# [5 rows x 101 columns]

# %%
data = data.drop_duplicates()  # removing duplicates

# %%
# convertion of weight to integer
weight =lambda x: int(x.replace('lbs',''))  # weight to integer
data['Weight']=list(map(weight, data['Weight']))

# %%
# convertion of height to integer
def height (x):
    x=x.replace('"','')
    f,i=x.split("\'")
    x=round(int(f)+int(i)/12,2)
    return x
data['Height']=list(map(height, data['Height']))

# %%
# convertion of amounts (€) to integer
def amount (x):
    x=x.replace('€','')
    if 'K' in x:
        scalar=1000
        x=x.replace('K','')
    elif 'M' in x:
        scalar=1000000
        x=x.replace('M','')
    else:
        scalar=1
    x=pd.to_numeric(x, errors='coerce')*scalar
    return x

# %%
data['Value']=list(map(amount, data['Value']))
data['Wage']=list(map(amount, data['Wage']))
data['Release Clause']=list(map(amount, data['Release Clause']))

# %%
data
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
#         BP   Position                               Team & Contract  Height  \
# 0       CM     CM CDM                 FC Lausanne-Sport 2015 ~ 2020    5.75
# 1       ST   ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan    6.00
# 2      CAM     CAM CF                          Al Hilal 2019 ~ 2022    5.33
# 3      CDM     CDM CM                      Swansea City 2016 ~ 2021    5.83
# 4      CDM     CDM CM        US Orléans Loiret Football 2018 ~ 2021    5.92
# ...    ...        ...                                           ...     ...
# 11696   LB         LB             Jagiellonia Białystok 2018 ~ 2021    6.08
# 11697   GK         GK                      ESTAC Troyes 2019 ~ 2022    6.08
# 11698   RM  LM CAM RM                    CD Antofagasta 2019 ~ 2024    5.50
# 11699   CM        NaN                                 Barnsley 2010    6.17
# 11700  CAM  ST CAM LM                  Portland Timbers 2019 ~ 2020    5.58
#
#        Weight  ...   CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0         161  ...  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1         159  ...  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2         134  ...  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
# 3         152  ...  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2   59
# 4         150  ...  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2   65
# ...       ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 11696     168  ...  60+2  60+2  63+2  63+2  61+2  61+2  61+2  63+2  16+2   65
# 11697     174  ...  26+2  26+2  25+2  24+2  26+2  26+2  26+2  24+2  69+2   70
# 11698     143  ...  44+2  44+2  49+2  45+2  35+2  35+2  35+2  45+2  17+2   67
# 11699     179  ...  68+0  68+0  66+0  64+0  60+0  60+0  60+0  64+0  25+0   68
# 11700     143  ...  43+2  43+2  46+2  44+2  36+2  36+2  36+2  44+2  15+2   64
#
# [11701 rows x 101 columns]

# %%
# clean the symbol '★' in those columns which have it
data['W/F'] = data['W/F'].str.rstrip('★').astype('int')
data['SM'] = data['SM'].str.rstrip('★').astype('int')
data['IR'] = data['IR'].str.rstrip('★').astype('int')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9336/2768304958.py in <module>
#       1 # clean the symbol '★' in those columns which have it
# ----> 2 data['W/F'] = data['W/F'].str.rstrip('★').astype('int')
#       3 data['SM'] = data['SM'].str.rstrip('★').astype('int')
#       4 data['IR'] = data['IR'].str.rstrip('★').astype('int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
data_num=data.select_dtypes(include = np.number)

# %%
data_num
# Out:
#            ID  Age  Height  Weight  Growth      Value   Wage  Release Clause  \
# 0      184383   26    5.75     161       1   525000.0   4000        801000.0
# 1      188044   30    6.00     159       0  8500000.0  23000             0.0
# 2      184431   33    5.33     134       0  9000000.0  49000      15300000.0
# 3      233796   22    5.83     152      13   275000.0   4000        694000.0
# 4      234799   23    5.92     150       8   725000.0   2000       1400000.0
# ...       ...  ...     ...     ...     ...        ...    ...             ...
# 11696  232504   25    6.08     168       5   625000.0   3000        891000.0
# 11697  214680   27    6.08     174       4  1600000.0   4000       2900000.0
# 11698  221489   22    5.50     143       8  1100000.0   2000       1700000.0
# 11699  146717   26    6.17     179       7        0.0      0             0.0
# 11700  236507   22    5.58     143       9   700000.0   2000       1200000.0
#
#        Attacking  Crossing  ...  W/F  SM  IR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 0            258        54  ...    4   2   1   69   51   63   63   51   60
# 1            365        66  ...    3   4   2   83   75   68   82   33   71
# 2            336        73  ...    4   4   2   80   77   78   86   27   56
# 3            242        44  ...    2   2   1   57   44   54   57   57   60
# 4            249        49  ...    2   3   1   66   44   60   64   60   66
# ...          ...       ...  ...  ...  ..  ..  ...  ...  ...  ...  ...  ...
# 11696        224        62  ...    3   2   1   75   28   56   59   60   69
# 11697         84        12  ...    2   1   1   72   67   66   72   40   70
# 11698        286        64  ...    3   3   1   76   60   60   72   26   43
# 11699        254        64  ...    3   1   3   72   63   70   72   57   66
# 11700        289        43  ...    3   3   1   79   62   56   67   24   48
#
#        OVA
# 0       64
# 1       77
# 2       80
# 3       59
# 4       65
# ...    ...
# 11696   65
# 11697   70
# 11698   67
# 11699   68
# 11700   64
#
# [11701 rows x 61 columns]

# %%
data_num.columns
# Out:
# Index(['ID', 'Age', 'Height', 'Weight', 'Growth', 'Value', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF',
#        'PHY', 'OVA'],
#       dtype='object')

# %%
selected_columns=data[['Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure']]
new_df = selected_columns.copy()
new_df
# Out:
#        Mentality  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0            290          54           52.0         62.0    68.0         54
# 1            313          54           33.0         78.0    72.0         76
# 2            332          75           26.0         80.0    78.0         73
# 3            257          61           57.0         31.0    54.0         54
# 4            294          66           60.0         55.0    64.0         49
# ...          ...         ...            ...          ...     ...        ...
# 11696        266          63           59.0         51.0    54.0         39
# 11697        101          30           22.0         15.0    15.0         19
# 11698        241          27           25.0         66.0    58.0         65
# 11699        241          64           61.0         63.0     NaN         53
# 11700        244          34           20.0         66.0    63.0         61
#
#        Composure
# 0           54.0
# 1           70.0
# 2           82.0
# 3           48.0
# 4           58.0
# ...          ...
# 11696       46.0
# 11697       56.0
# 11698       58.0
# 11699        NaN
# 11700       56.0
#
# [11701 rows x 7 columns]

# %%
new_df.isna().sum()
# Out:
# Mentality          0
# Aggression         0
# Interceptions      7
# Positioning        7
# Vision            41
# Penalties          0
# Composure        279
# dtype: int64

# %%
for col in new_df.columns:
    column_mean=int(new_df[col].mean())
    new_df[col]=new_df[col].fillna(column_mean)

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y=new_df['Mentality']
X=new_df.drop(['Mentality'], axis=1)

# %%
lm = linear_model.LinearRegression()

# %%
lm.fit(X,y)
print(lm.intercept_)
# Out:
# -0.4754730643286962

# %%
correlations_matrix = new_df.corr()
sns.heatmap(correlations_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
data_num=data_num.drop(['Crossing', 'Finishing','Heading Accuracy', 'Short Passing', 'Volleys', 'Dribbling',
                         'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
                         'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
                         'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
                         'Aggression', 'Interceptions', 'Positioning', 'Vision',
                         'Penalties', 'Composure', 'Marking', 'Standing Tackle',
                         'Sliding Tackle', 'GK Diving', 'GK Handling',
                         'GK Kicking', 'GK Positioning', 'GK Reflexes', 
                         'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY'], axis=1)

# %%
data_num
# Out:
#            ID  Age  Growth  Attacking  Skill  Movement  Power  Mentality  \
# 0      184383   26       1        258    286       346    306        290
# 1      188044   30       0        365    375       404    372        313
# 2      184431   33       0        336    424       424    308        332
# 3      233796   22      13        242    259       282    277        257
# 4      234799   23       8        249    280       324    280        294
# ...       ...  ...     ...        ...    ...       ...    ...        ...
# 11696  232504   25       5        224    248       333    273        266
# 11697  214680   27       4         84     96       237    217        101
# 11698  221489   22       8        286    291       388    278        241
# 11699  146717   26       7        254    284       198    258        241
# 11700  236507   22       9        289    267       391    312        244
#
#        Defending  Goalkeeping  Total Stats  Base Stats  OVA
# 0            148           48         1682         357   64
# 1             77           55         1961         412   77
# 2             80           21         1925         404   80
# 3            168           42         1527         329   59
# 4            185           52         1664         360   65
# ...          ...          ...          ...         ...  ...
# 11696        184           61         1589         347   65
# 11697         41          347         1123         387   70
# 11698         62           57         1603         337   67
# 11699        113           81         1429         400   68
# 11700         56           48         1607         336   64
#
# [11701 rows x 13 columns]

# %%
round(data_num.isna().sum()/len(data_num),4)*100
# Out:
# ID             0.0
# Age            0.0
# Growth         0.0
# Attacking      0.0
# Skill          0.0
# Movement       0.0
# Power          0.0
# Mentality      0.0
# Defending      0.0
# Goalkeeping    0.0
# Total Stats    0.0
# Base Stats     0.0
# OVA            0.0
# dtype: float64

# %%
data_num.describe()
# Out:
#                   ID          Age        Growth     Attacking         Skill  \
# count   11701.000000  11701.00000  11701.000000  11701.000000  11701.000000
# mean   219436.649004     25.27049      5.534655    258.482181    266.497222
# std     37480.006004      4.95764      5.810903     72.267012     76.835287
# min        27.000000     16.00000     -1.000000     33.000000     43.000000
# 25%    204060.000000     21.00000      0.000000    232.000000    232.000000
# 50%    229040.000000     25.00000      4.000000    271.000000    279.000000
# 75%    244176.000000     29.00000     10.000000    306.000000    319.000000
# max    259090.000000     43.00000     26.000000    437.000000    470.000000
#
#            Movement         Power     Mentality     Defending   Goalkeeping  \
# count  11701.000000  11701.000000  11701.000000  11701.000000  11701.000000
# mean     322.617383    302.083326    261.704982    140.674558     77.726946
# std       55.330054     49.697749     62.935298     61.599006     81.221525
# min      113.000000    133.000000     55.000000     17.000000     12.000000
# 25%      294.000000    271.000000    235.000000     83.000000     48.000000
# 50%      331.000000    308.000000    269.000000    156.000000     53.000000
# 75%      361.000000    339.000000    304.000000    194.000000     59.000000
# max      464.000000    444.000000    414.000000    267.000000    439.000000
#
#         Total Stats    Base Stats           OVA
# count  11701.000000  11701.000000  11701.000000
# mean    1629.786599    361.106316     66.921972
# std      260.766470     40.318331      6.876081
# min      731.000000    228.000000     38.000000
# 25%     1490.000000    333.000000     62.000000
# 50%     1659.000000    362.000000     67.000000
# 75%     1811.000000    389.000000     72.000000
# max     2304.000000    490.000000     93.000000

# %%
data_cat=data.select_dtypes(include = object)
data_cat
# Out:
#                  Name  Nationality                        Club   BP  \
# 0           A. Pasche  Switzerland           FC Lausanne-Sport   CM
# 1       Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST
# 2         S. Giovinco        Italy                    Al Hilal  CAM
# 3            J. Evans        Wales                Swansea City  CDM
# 4          Y. Demoncy       France  US Orléans Loiret Football  CDM
# ...               ...          ...                         ...  ...
# 11696   B. Böðvarsson      Iceland       Jagiellonia Białystok   LB
# 11697       G. Gallon       France                ESTAC Troyes   GK
# 11698       J. Flores        Chile              CD Antofagasta   RM
# 11699  Anderson Silva       Brazil                    Barnsley   CM
# 11700     T. Conechny    Argentina            Portland Timbers  CAM
#
#         Position                               Team & Contract Height  Weight  \
# 0         CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs
# 1       ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs
# 2         CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs
# 3         CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs
# 4         CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs
# ...          ...                                           ...    ...     ...
# 11696         LB             Jagiellonia Białystok 2018 ~ 2021   6'1"  168lbs
# 11697         GK                      ESTAC Troyes 2019 ~ 2022   6'1"  174lbs
# 11698  LM CAM RM                    CD Antofagasta 2019 ~ 2024   5'6"  143lbs
# 11699        NaN                                 Barnsley 2010   6'2"  179lbs
# 11700  ST CAM LM                  Portland Timbers 2019 ~ 2020   5'7"  143lbs
#
#         foot        Joined  ...   LDM   CDM   RDM   RWB    LB   LCB    CB  \
# 0      Right   Jul 1, 2015  ...  59+1  59+1  59+1  59+1  58+1  54+1  54+1
# 1      Right  Jan 16, 2015  ...  53+2  53+2  53+2  57+2  53+2  48+2  48+2
# 2      Right  Jan 31, 2019  ...  56+2  56+2  56+2  59+2  53+2  41+2  41+2
# 3      Right   Jul 1, 2016  ...  58+2  58+2  58+2  56+2  57+2  58+2  58+2
# 4      Right   Jul 1, 2018  ...  64+2  64+2  64+2  64+2  63+2  61+2  61+2
# ...      ...           ...  ...   ...   ...   ...   ...   ...   ...   ...
# 11696   Left   Feb 8, 2018  ...  60+2  60+2  60+2  63+2  63+2  61+2  61+2
# 11697  Right   Jul 1, 2019  ...  26+2  26+2  26+2  25+2  24+2  26+2  26+2
# 11698  Right  Jan 23, 2019  ...  44+2  44+2  44+2  49+2  45+2  35+2  35+2
# 11699  Right           NaN  ...  68+0  68+0  68+0  66+0  64+0  60+0  60+0
# 11700   Left  Jul 22, 2019  ...  43+2  43+2  43+2  46+2  44+2  36+2  36+2
#
#         RCB    RB    GK
# 0      54+1  58+1  15+1
# 1      48+2  53+2  18+2
# 2      41+2  53+2  12+2
# 3      58+2  57+2  14+2
# 4      61+2  63+2  15+2
# ...     ...   ...   ...
# 11696  61+2  63+2  16+2
# 11697  26+2  24+2  69+2
# 11698  35+2  45+2  17+2
# 11699  60+0  64+0  25+0
# 11700  36+2  44+2  15+2
#
# [11701 rows x 48 columns]

# %%
data_cat = data_cat.drop(['Name','Nationality','Club', 'Position', 'Team & Contract', 'Joined', 'Loan Date End', 'Contract'], axis=1)

# %%
round(data_cat.isna().sum()/len(data_cat),4)*100  # No null values
# Out:
# BP                0.0
# Height            0.0
# Weight            0.0
# foot              0.0
# Value             0.0
# Wage              0.0
# Release Clause    0.0
# W/F               0.0
# SM                0.0
# A/W               0.5
# D/W               0.5
# IR                0.0
# Hits              0.0
# LS                0.0
# ST                0.0
# RS                0.0
# LW                0.0
# LF                0.0
# CF                0.0
# RF                0.0
# RW                0.0
# LAM               0.0
# CAM               0.0
# RAM               0.0
# LM                0.0
# LCM               0.0
# CM                0.0
# RCM               0.0
# RM                0.0
# LWB               0.0
# LDM               0.0
# CDM               0.0
# RDM               0.0
# RWB               0.0
# LB                0.0
# LCB               0.0
# CB                0.0
# RCB               0.0
# RB                0.0
# GK                0.0
# dtype: float64

# %%
data_cat['A/W'].value_counts(dropna=False)
# Out:
# Medium    7494
# High      3548
# Low        600
# NaN         59
# Name: A/W, dtype: int64

# %%
data_cat['A/W']=data_cat['A/W'].fillna('Medium')

# %%
data_cat['D/W'].value_counts(dropna=False)
# Out:
# Medium    8350
# High      2027
# Low       1265
# NaN         59
# Name: D/W, dtype: int64

# %%
data_cat['D/W']=data_cat['D/W'].fillna('Medium')

# %%
data_cat
# Out:
#         BP Height  Weight   foot  Value  Wage Release Clause  W/F  SM     A/W  \
# 0       CM   5'9"  161lbs  Right  €525K   €4K          €801K  4 ★  2★    High
# 1       ST   6'0"  159lbs  Right  €8.5M  €23K             €0  3 ★  4★    High
# 2      CAM   5'4"  134lbs  Right    €9M  €49K         €15.3M  4 ★  4★    High
# 3      CDM  5'10"  152lbs  Right  €275K   €4K          €694K  2 ★  2★  Medium
# 4      CDM  5'11"  150lbs  Right  €725K   €2K          €1.4M  2 ★  3★     Low
# ...    ...    ...     ...    ...    ...   ...            ...  ...  ..     ...
# 11696   LB   6'1"  168lbs   Left  €625K   €3K          €891K  3 ★  2★  Medium
# 11697   GK   6'1"  174lbs  Right  €1.6M   €4K          €2.9M  2 ★  1★  Medium
# 11698   RM   5'6"  143lbs  Right  €1.1M   €2K          €1.7M  3 ★  3★    High
# 11699   CM   6'2"  179lbs  Right     €0    €0             €0  3 ★  1★  Medium
# 11700  CAM   5'7"  143lbs   Left  €700K   €2K          €1.2M  3 ★  3★    High
#
#        ...   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK
# 0      ...  59+1  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1
# 1      ...  53+2  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2
# 2      ...  56+2  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2
# 3      ...  58+2  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2
# 4      ...  64+2  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 11696  ...  60+2  60+2  60+2  63+2  63+2  61+2  61+2  61+2  63+2  16+2
# 11697  ...  26+2  26+2  26+2  25+2  24+2  26+2  26+2  26+2  24+2  69+2
# 11698  ...  44+2  44+2  44+2  49+2  45+2  35+2  35+2  35+2  45+2  17+2
# 11699  ...  68+0  68+0  68+0  66+0  64+0  60+0  60+0  60+0  64+0  25+0
# 11700  ...  43+2  43+2  43+2  46+2  44+2  36+2  36+2  36+2  44+2  15+2
#
# [11701 rows x 40 columns]

# %%
# Out:
# 50

# %%
data_cat
